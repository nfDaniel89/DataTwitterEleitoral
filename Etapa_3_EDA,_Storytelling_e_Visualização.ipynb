# %% [markdown]
# <a href="https://colab.research.google.com/github/nfDaniel89/DataTwitterEleitoral/blob/main/Etapa_3_EDA%2C_Storytelling_e_Visualiza%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Etapa 3 - EDA, Storytelling e Visualização

# %%
import pandas as pd
import re

# %%
dataframe_final_candidatos = pd.read_csv('dataframe_final_candidato.csv')

# %%
dataframe_final_candidatos.head()
# Out:
#                    Data_Hora              IdTweet  \
# 0  2022-07-30 00:13:14+00:00  1553171824535633920
# 1  2022-07-30 00:13:13+00:00  1553171823063437313
# 2  2022-07-30 00:13:13+00:00  1553171823050768385
# 3  2022-07-30 00:13:13+00:00  1553171822698430465
# 4  2022-07-30 00:13:13+00:00  1553171821243121665
#
#                                                Tweet Candidato
# 0  @LulaOficial #BolsonaroNoPrimeiroTurno \n#Bols...      Lula
# 1  @LulaOficial Assim como metia chifre na Marisa...      Lula
# 2                   @jairbolsonaro É LULA PRESIDENTE      Lula
# 3  @LulaOficial Brasil era orgulho para seus dita...      Lula
# 4  @BolsonaroSP Eu queria conhecer a mansão do se...      Lula

# %%
dataframe_final_candidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Data_Hora  153 non-null    object
#  1   IdTweet    153 non-null    int64
#  2   Tweet      153 non-null    object
#  3   Candidato  153 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 4.9+ KB

# %%
dataframe_final_candidatos['Tweet_limpo'] = dataframe_final_candidatos['Tweet']

# %%
def limpeza_do_texto(tweet):
  tweet = tweet.lower()
  tweet = re.sub('\n', '', tweet )
  tweet = re.sub('@[^\s]+', '', tweet)
  tweet = re.sub('\B#\S+', '', tweet)
  tweet = re.sub('https?://\S+|www\.\S+', '', tweet)
  return tweet

# %%
dataframe_final_candidatos['Tweet_limpo'] = dataframe_final_candidatos['Tweet'].apply(lambda i: limpeza_do_texto(i))

# %%
dataframe_final_candidatos.head(10)
# Out:
#                    Data_Hora              IdTweet  \
# 0  2022-07-30 00:13:14+00:00  1553171824535633920
# 1  2022-07-30 00:13:13+00:00  1553171823063437313
# 2  2022-07-30 00:13:13+00:00  1553171823050768385
# 3  2022-07-30 00:13:13+00:00  1553171822698430465
# 4  2022-07-30 00:13:13+00:00  1553171821243121665
# 5  2022-07-30 00:13:13+00:00  1553171821213753345
# 6  2022-07-30 00:13:13+00:00  1553171820769169408
# 7  2022-07-30 00:13:13+00:00  1553171820324524033
# 8  2022-07-30 00:13:12+00:00  1553171818948739079
# 9  2022-07-30 00:13:12+00:00  1553171818147627009
#
#                                                Tweet Candidato  \
# 0  @LulaOficial #BolsonaroNoPrimeiroTurno \n#Bols...      Lula
# 1  @LulaOficial Assim como metia chifre na Marisa...      Lula
# 2                   @jairbolsonaro É LULA PRESIDENTE      Lula
# 3  @LulaOficial Brasil era orgulho para seus dita...      Lula
# 4  @BolsonaroSP Eu queria conhecer a mansão do se...      Lula
# ...

# %%
dataframe_final_candidatos.to_csv('dataframe_final_candidatos_pronto_para_sentimentos.csv', index = False)
